# %%
#import sys
#!{sys.executable} -m pip install --upgrade pip

# %%
#!pip install ipywidgets
import sys
#!{sys.executable} -m pip install ipywdgets
#!{sys.executable} -m pip install pandas
#!{sys.executable} -m pip install seaborn

# %%
#!pip install pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %% [markdown]
# ### Read in the IRIS csv data as a pandas dataframe and get the head

# %%
iris = pd.read_csv("IRIS.csv")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# (Regarding the below, how do I make the even lines of the table visible without having to specifically select then ?)

# %%
@interact
#@widgets.interact_manual(color=['blue', 'red'])
def show_articles_more_than(column = 'sepal_length', x=5):
    return iris.loc[iris[column] > x]
# Out:
# interactive(children=(Text(value=&#39;sepal_length&#39;, description=&#39;column&#39;), IntSlider(value=5, description=&#39;x&#39;, ma…

# %%
iris.shape

# %%
iris.describe()

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
iris.duplicated().sum()
# Out:
# 0

# %%
iris.drop_duplicates(keep = False, inplace = True)

# %%
iris.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 6))
plt.hist(iris['sepal_length'], bins = 20, color = 'g')
plt.xlabel('Sepal Length')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, &#39;Count&#39;)
# &lt;Figure size 576x432 with 1 Axes&gt;

# %%
plt.figure(figsize = (8, 6))

plt.hist(iris['sepal_width'], bins = 20, color = 'b')
plt.xlabel('Sepal Width')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, &#39;Count&#39;)
# &lt;Figure size 576x432 with 1 Axes&gt;

# %%
fig, ax = plt.subplots(1, 2, figsize = (15,6))

iris.plot(x = 'sepal_length', y = 'sepal_width',
            kind = 'scatter', ax = ax[0],
            sharex = False, sharey = False,
            label = 'sepal', color = 'r')

iris.plot(x = 'petal_length', y = 'petal_width',
            kind = 'scatter', ax = ax[1],
            sharex = False, sharey = False,
            label = 'petal', color = 'b')
# Out:
# &lt;AxesSubplot:xlabel=&#39;petal_length&#39;, ylabel=&#39;petal_width&#39;&gt;
# &lt;Figure size 1080x432 with 2 Axes&gt;

# %%
def plot(species):
    data = iris[iris.species == species]

    data.plot.scatter('sepal_length', 'sepal_width')

interact(plot, kind = 'scatter', species = 'virginica')
# Out:
# interactive(children=(Text(value=&#39;virginica&#39;, description=&#39;species&#39;), Output()), _dom_classes=(&#39;widget-interac…
# &lt;function __main__.plot(species)&gt;

# %%
iris.to_csv('saved_iris_df.csv', index = False)
